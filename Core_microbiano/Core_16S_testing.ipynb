# %%
import json
import pandas as pd
import os
# import matplotlib

# %% [markdown]
# ## To do:
#
# - Organize by metadata
#     - Check metadata [X]
#     - Identify each sample belonging to a metadata [X]
#     - Generate subdfs based on metadata [X]
#
# - Generate the Venn diagram
#
# - Based on genus []
# - Based on family []
# - Based on class []
# - Based on phylum []

# %%
def normalize_dataframe(dataframe, criteria=0):       
    
    row_number, col_number = dataframe.shape
    
    for row in range(0, row_number):
        for col in range(0, col_number):
            if dataframe.iloc[row, col] >= criteria:
                dataframe.iloc[row, col] = 1
            else:
                dataframe.iloc[row, col] = 0
                
    return dataframe

# %%
# Import the count file
counts = pd.read_csv("absolute_numbers_taxonomy_lvl_7_filtered.tsv", sep='\t', header=0, index_col=0)

# %%
counts
# Out:
#                              d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;__;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      3.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  2.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                 74.0
# T120-8-VALD-3-PL-205-Cistus                                                6.0
#
#                              d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;g__Candidatus_Nitrocosmicus;s__uncultured_crenarchaeote  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                     14.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                    202.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                               61.0
# T120-19-AND-PL-238-Cistus                                                 25.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  6.0
# T120-25-BAD-PL-257-Cistus                                                 47.0
# T120-28-BAD-PL-266-Cistus                                                 21.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                 56.0
# T120-6-VALD-PL-198-Cistus                                                253.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;g__Nitrososphaeraceae;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  3.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Archaea;p__Euryarchaeota;c__Methanobacteria;o__Methanobacteriales;f__Methanobacteriaceae;g__Methanobacterium;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  3.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Archaea;p__Halobacterota;c__Methanosarcinia;o__Methanosarciniales;f__Methanosarcinaceae;g__Methanosarcina;s__Methanosarcina_thermophila  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      7.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                 12.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;__;__;__;__;__;__  \
# #OTU ID
# C-1-Cistus                                             0.0
# C-11-AND-PL-31-Cistus                                468.0
# C-14-AND-PL-41-Cistus                                 77.0
# C-15-AND-PL-44-Cistus                                713.0
# C-16-AND-PL-47-Cistus                                 84.0
# C-2-Cistus                                             0.0
# C-20-AND-PL-59-Cistus                                 44.0
# C-23-BAD-PL-68-Cistus                                 33.0
# C-24-BAD-PL-71-Cistus                                209.0
# C-25-BAD-PL-74-Cistus                                679.0
# C-28-BAD-PL-83-Cistus                                132.0
# C-3-Cistus                                             0.0
# C-30-BAD-PL-89-Cistus                                116.0
# T120-1-Cistus                                          0.0
# T120-11-AND-PL-214-Cistus                            230.0
# T120-12-AND-PL-217-Cistus                            254.0
# T120-16-AND-2-PL-229-Cistus                           83.0
# T120-19-AND-PL-238-Cistus                             65.0
# T120-2-Cistus                                          0.0
# T120-21-BAD-PL-245-Cistus                             90.0
# T120-25-BAD-PL-257-Cistus                             87.0
# T120-28-BAD-PL-266-Cistus                            162.0
# T120-3-Cistus                                          0.0
# T120-4-VALD-PL-192-Cistus                            749.0
# T120-6-VALD-PL-198-Cistus                             45.0
# T120-8-VALD-3-PL-205-Cistus                          120.0
#
#                              d__Bacteria;p__Abditibacteriota;c__Abditibacteria;o__Abditibacteriales;f__Abditibacteriaceae;g__Abditibacterium;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                     12.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                 14.0
# T120-28-BAD-PL-266-Cistus                                                 11.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Abditibacteriota;c__Abditibacteria;o__Abditibacteriales;f__Abditibacteriaceae;g__Abditibacterium;s__uncultured_bacterium  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                     16.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      4.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                 12.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Acidobacteriota;c__Acidobacteriae;__;__;__;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                     13.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                 11.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Acidobacteriota;c__Acidobacteriae;o__Acidobacteriae;f__Acidobacteriae;g__Paludibaculum;s__metagenome  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  5.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              ...  \
# #OTU ID                      ...
# C-1-Cistus                   ...
# C-11-AND-PL-31-Cistus        ...
# C-14-AND-PL-41-Cistus        ...
# C-15-AND-PL-44-Cistus        ...
# C-16-AND-PL-47-Cistus        ...
# C-2-Cistus                   ...
# C-20-AND-PL-59-Cistus        ...
# C-23-BAD-PL-68-Cistus        ...
# C-24-BAD-PL-71-Cistus        ...
# C-25-BAD-PL-74-Cistus        ...
# C-28-BAD-PL-83-Cistus        ...
# C-3-Cistus                   ...
# C-30-BAD-PL-89-Cistus        ...
# T120-1-Cistus                ...
# T120-11-AND-PL-214-Cistus    ...
# T120-12-AND-PL-217-Cistus    ...
# T120-16-AND-2-PL-229-Cistus  ...
# T120-19-AND-PL-238-Cistus    ...
# T120-2-Cistus                ...
# T120-21-BAD-PL-245-Cistus    ...
# T120-25-BAD-PL-257-Cistus    ...
# T120-28-BAD-PL-266-Cistus    ...
# T120-3-Cistus                ...
# T120-4-VALD-PL-192-Cistus    ...
# T120-6-VALD-PL-198-Cistus    ...
# T120-8-VALD-3-PL-205-Cistus  ...
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Chthoniobacterales;f__Terrimicrobiaceae;g__Terrimicrobium;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                     39.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                    123.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Chthoniobacterales;f__Xiphinematobacteraceae;g__Candidatus_Xiphinematobacter;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      8.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# ...
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                     56.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                 11.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Pedosphaeraceae;__  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                     55.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                    196.0
# C-16-AND-PL-47-Cistus                                                     16.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                     19.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                     48.0
# C-28-BAD-PL-83-Cistus                                                     13.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                     45.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                 35.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                4.0
# T120-19-AND-PL-238-Cistus                                                 24.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                 40.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  1.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Pedosphaeraceae;s__uncultured_Pedosphaera  \
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                 14.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__uncultured;__
# #OTU ID
# C-1-Cistus                                                                 0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                     22.0
# C-2-Cistus                                                                 0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-3-Cistus                                                                 0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-1-Cistus                                                              0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-2-Cistus                                                              0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-3-Cistus                                                              0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
# [26 rows x 858 columns]

# %%
# Import the metadata file so it matches with the counts)
metadata = pd.read_csv("metadata.tsv", sep='\t', header=0, index_col=0)

# %%
metadata
# Out:
#                                    Planta_spp     localidad  Sample_from  \
# sample-id
# C-1-Cistus                   Cistus ladanifer  Valdemaqueda         Seed
# C-2-Cistus                   Cistus ladanifer       Andujar         Seed
# C-3-Cistus                   Cistus ladanifer       Badajoz         Seed
# T120-1-Cistus                Cistus ladanifer  Valdemaqueda         Seed
# T120-2-Cistus                Cistus ladanifer       Andujar         Seed
# T120-3-Cistus                Cistus ladanifer       Badajoz         Seed
# C-11-AND-PL-31-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-14-AND-PL-41-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-15-AND-PL-44-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-16-AND-PL-47-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-20-AND-PL-59-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-23-BAD-PL-68-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-24-BAD-PL-71-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-25-BAD-PL-74-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-28-BAD-PL-83-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-30-BAD-PL-89-Cistus        Cistus ladanifer       Badajoz  Grown plant
# T120-11-AND-PL-214-Cistus    Cistus ladanifer       Andujar  Grown plant
# T120-12-AND-PL-217-Cistus    Cistus ladanifer       Andujar  Grown plant
# T120-16-AND-2-PL-229-Cistus  Cistus ladanifer       Andujar  Grown plant
# T120-19-AND-PL-238-Cistus    Cistus ladanifer       Andujar  Grown plant
# T120-21-BAD-PL-245-Cistus    Cistus ladanifer       Badajoz  Grown plant
# T120-25-BAD-PL-257-Cistus    Cistus ladanifer       Badajoz  Grown plant
# T120-28-BAD-PL-266-Cistus    Cistus ladanifer       Badajoz  Grown plant
# T120-4-VALD-PL-192-Cistus    Cistus ladanifer  Valdemaqueda  Grown plant
# T120-6-VALD-PL-198-Cistus    Cistus ladanifer  Valdemaqueda  Grown plant
# T120-8-VALD-3-PL-205-Cistus  Cistus ladanifer  Valdemaqueda  Grown plant
#
#                              Treatment
# sample-id
# C-1-Cistus                     Control
# C-2-Cistus                     Control
# C-3-Cistus                     Control
# T120-1-Cistus                120_10min
# T120-2-Cistus                120_10min
# T120-3-Cistus                120_10min
# C-11-AND-PL-31-Cistus          Control
# C-14-AND-PL-41-Cistus          Control
# C-15-AND-PL-44-Cistus          Control
# C-16-AND-PL-47-Cistus          Control
# C-20-AND-PL-59-Cistus          Control
# C-23-BAD-PL-68-Cistus          Control
# C-24-BAD-PL-71-Cistus          Control
# C-25-BAD-PL-74-Cistus          Control
# C-28-BAD-PL-83-Cistus          Control
# C-30-BAD-PL-89-Cistus          Control
# T120-11-AND-PL-214-Cistus    120_10min
# T120-12-AND-PL-217-Cistus    120_10min
# T120-16-AND-2-PL-229-Cistus  120_10min
# T120-19-AND-PL-238-Cistus    120_10min
# T120-21-BAD-PL-245-Cistus    120_10min
# T120-25-BAD-PL-257-Cistus    120_10min
# T120-28-BAD-PL-266-Cistus    120_10min
# T120-4-VALD-PL-192-Cistus    120_10min
# T120-6-VALD-PL-198-Cistus    120_10min
# T120-8-VALD-3-PL-205-Cistus  120_10min

# %%
# get the categories
# if more than one category, add it to divide by later

valid_categories = dict()
category_names_list = list(metadata.columns)

# get all different possibilities for each metadata column
for col_index in range(metadata.shape[1]):
    
    # list from a set to avoid repeating
    groups = (list(set(metadata[category_names_list[col_index]])))
    
    # if more than 1 different category, add it to the dict
    if len(groups) > 1:
        category_name = category_names_list[col_index]
        valid_categories[category_name] = [item for item in groups]

print(valid_categories)
# Out:
# {'localidad': ['Valdemaqueda', 'Badajoz', 'Andujar'], 'Sample_from': ['Seed', 'Grown plant'], 'Treatment': ['120_10min', 'Control']}

# %%
# generate the full dataframe
full_df = pd.concat([metadata, counts], axis=1)
full_df
# Out:
#                                    Planta_spp     localidad  Sample_from  \
# C-1-Cistus                   Cistus ladanifer  Valdemaqueda         Seed
# C-2-Cistus                   Cistus ladanifer       Andujar         Seed
# C-3-Cistus                   Cistus ladanifer       Badajoz         Seed
# T120-1-Cistus                Cistus ladanifer  Valdemaqueda         Seed
# T120-2-Cistus                Cistus ladanifer       Andujar         Seed
# T120-3-Cistus                Cistus ladanifer       Badajoz         Seed
# C-11-AND-PL-31-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-14-AND-PL-41-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-15-AND-PL-44-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-16-AND-PL-47-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-20-AND-PL-59-Cistus        Cistus ladanifer       Andujar  Grown plant
# C-23-BAD-PL-68-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-24-BAD-PL-71-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-25-BAD-PL-74-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-28-BAD-PL-83-Cistus        Cistus ladanifer       Badajoz  Grown plant
# C-30-BAD-PL-89-Cistus        Cistus ladanifer       Badajoz  Grown plant
# T120-11-AND-PL-214-Cistus    Cistus ladanifer       Andujar  Grown plant
# T120-12-AND-PL-217-Cistus    Cistus ladanifer       Andujar  Grown plant
# T120-16-AND-2-PL-229-Cistus  Cistus ladanifer       Andujar  Grown plant
# T120-19-AND-PL-238-Cistus    Cistus ladanifer       Andujar  Grown plant
# T120-21-BAD-PL-245-Cistus    Cistus ladanifer       Badajoz  Grown plant
# T120-25-BAD-PL-257-Cistus    Cistus ladanifer       Badajoz  Grown plant
# T120-28-BAD-PL-266-Cistus    Cistus ladanifer       Badajoz  Grown plant
# T120-4-VALD-PL-192-Cistus    Cistus ladanifer  Valdemaqueda  Grown plant
# T120-6-VALD-PL-198-Cistus    Cistus ladanifer  Valdemaqueda  Grown plant
# T120-8-VALD-3-PL-205-Cistus  Cistus ladanifer  Valdemaqueda  Grown plant
#
#                              Treatment  \
# C-1-Cistus                     Control
# C-2-Cistus                     Control
# C-3-Cistus                     Control
# T120-1-Cistus                120_10min
# T120-2-Cistus                120_10min
# T120-3-Cistus                120_10min
# C-11-AND-PL-31-Cistus          Control
# C-14-AND-PL-41-Cistus          Control
# C-15-AND-PL-44-Cistus          Control
# C-16-AND-PL-47-Cistus          Control
# C-20-AND-PL-59-Cistus          Control
# C-23-BAD-PL-68-Cistus          Control
# C-24-BAD-PL-71-Cistus          Control
# C-25-BAD-PL-74-Cistus          Control
# C-28-BAD-PL-83-Cistus          Control
# C-30-BAD-PL-89-Cistus          Control
# T120-11-AND-PL-214-Cistus    120_10min
# T120-12-AND-PL-217-Cistus    120_10min
# T120-16-AND-2-PL-229-Cistus  120_10min
# T120-19-AND-PL-238-Cistus    120_10min
# T120-21-BAD-PL-245-Cistus    120_10min
# T120-25-BAD-PL-257-Cistus    120_10min
# T120-28-BAD-PL-266-Cistus    120_10min
# T120-4-VALD-PL-192-Cistus    120_10min
# T120-6-VALD-PL-198-Cistus    120_10min
# T120-8-VALD-3-PL-205-Cistus  120_10min
#
#                              d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;__;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      3.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  2.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                 74.0
# T120-8-VALD-3-PL-205-Cistus                                                6.0
#
#                              d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;g__Candidatus_Nitrocosmicus;s__uncultured_crenarchaeote  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                     14.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                    202.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                               61.0
# T120-19-AND-PL-238-Cistus                                                 25.0
# T120-21-BAD-PL-245-Cistus                                                  6.0
# T120-25-BAD-PL-257-Cistus                                                 47.0
# T120-28-BAD-PL-266-Cistus                                                 21.0
# T120-4-VALD-PL-192-Cistus                                                 56.0
# T120-6-VALD-PL-198-Cistus                                                253.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;g__Nitrososphaeraceae;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  3.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Archaea;p__Euryarchaeota;c__Methanobacteria;o__Methanobacteriales;f__Methanobacteriaceae;g__Methanobacterium;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  3.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Archaea;p__Halobacterota;c__Methanosarcinia;o__Methanosarciniales;f__Methanosarcinaceae;g__Methanosarcina;s__Methanosarcina_thermophila  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      7.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                 12.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;__;__;__;__;__;__  ...  \
# C-1-Cistus                                             0.0  ...
# C-2-Cistus                                             0.0  ...
# C-3-Cistus                                             0.0  ...
# T120-1-Cistus                                          0.0  ...
# T120-2-Cistus                                          0.0  ...
# T120-3-Cistus                                          0.0  ...
# C-11-AND-PL-31-Cistus                                468.0  ...
# C-14-AND-PL-41-Cistus                                 77.0  ...
# C-15-AND-PL-44-Cistus                                713.0  ...
# C-16-AND-PL-47-Cistus                                 84.0  ...
# C-20-AND-PL-59-Cistus                                 44.0  ...
# C-23-BAD-PL-68-Cistus                                 33.0  ...
# C-24-BAD-PL-71-Cistus                                209.0  ...
# C-25-BAD-PL-74-Cistus                                679.0  ...
# C-28-BAD-PL-83-Cistus                                132.0  ...
# C-30-BAD-PL-89-Cistus                                116.0  ...
# T120-11-AND-PL-214-Cistus                            230.0  ...
# T120-12-AND-PL-217-Cistus                            254.0  ...
# T120-16-AND-2-PL-229-Cistus                           83.0  ...
# T120-19-AND-PL-238-Cistus                             65.0  ...
# T120-21-BAD-PL-245-Cistus                             90.0  ...
# T120-25-BAD-PL-257-Cistus                             87.0  ...
# T120-28-BAD-PL-266-Cistus                            162.0  ...
# T120-4-VALD-PL-192-Cistus                            749.0  ...
# T120-6-VALD-PL-198-Cistus                             45.0  ...
# T120-8-VALD-3-PL-205-Cistus                          120.0  ...
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Chthoniobacterales;f__Terrimicrobiaceae;g__Terrimicrobium;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                     39.0
# C-30-BAD-PL-89-Cistus                                                    123.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Chthoniobacterales;f__Xiphinematobacteraceae;g__Candidatus_Xiphinematobacter;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      8.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  8.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;__;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                    207.0
# C-15-AND-PL-44-Cistus                                                    508.0
# C-16-AND-PL-47-Cistus                                                    351.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                    156.0
# C-24-BAD-PL-71-Cistus                                                    120.0
# C-25-BAD-PL-74-Cistus                                                    611.0
# C-28-BAD-PL-83-Cistus                                                    499.0
# C-30-BAD-PL-89-Cistus                                                    504.0
# T120-11-AND-PL-214-Cistus                                                261.0
# T120-12-AND-PL-217-Cistus                                                343.0
# T120-16-AND-2-PL-229-Cistus                                              128.0
# T120-19-AND-PL-238-Cistus                                                 88.0
# T120-21-BAD-PL-245-Cistus                                                 75.0
# T120-25-BAD-PL-257-Cistus                                                 86.0
# T120-28-BAD-PL-266-Cistus                                                291.0
# T120-4-VALD-PL-192-Cistus                                                153.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                              346.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__ADurb.Bin063-1;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      5.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  9.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Ellin516;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                 35.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Ellin516;s__metagenome  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                     18.0
# ...
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Ellin517;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                     56.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                 11.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Pedosphaeraceae;__  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                     55.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                    196.0
# C-16-AND-PL-47-Cistus                                                     16.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                     19.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                     48.0
# C-28-BAD-PL-83-Cistus                                                     13.0
# C-30-BAD-PL-89-Cistus                                                     45.0
# T120-11-AND-PL-214-Cistus                                                 35.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                4.0
# T120-19-AND-PL-238-Cistus                                                 24.0
# T120-21-BAD-PL-245-Cistus                                                 40.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  1.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__Pedosphaeraceae;s__uncultured_Pedosphaera  \
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                      0.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                 14.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
#                              d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Pedosphaerales;f__Pedosphaeraceae;g__uncultured;__
# C-1-Cistus                                                                 0.0
# C-2-Cistus                                                                 0.0
# C-3-Cistus                                                                 0.0
# T120-1-Cistus                                                              0.0
# T120-2-Cistus                                                              0.0
# T120-3-Cistus                                                              0.0
# C-11-AND-PL-31-Cistus                                                      0.0
# C-14-AND-PL-41-Cistus                                                      0.0
# C-15-AND-PL-44-Cistus                                                      0.0
# C-16-AND-PL-47-Cistus                                                     22.0
# C-20-AND-PL-59-Cistus                                                      0.0
# C-23-BAD-PL-68-Cistus                                                      0.0
# C-24-BAD-PL-71-Cistus                                                      0.0
# C-25-BAD-PL-74-Cistus                                                      0.0
# C-28-BAD-PL-83-Cistus                                                      0.0
# C-30-BAD-PL-89-Cistus                                                      0.0
# T120-11-AND-PL-214-Cistus                                                  0.0
# T120-12-AND-PL-217-Cistus                                                  0.0
# T120-16-AND-2-PL-229-Cistus                                                0.0
# T120-19-AND-PL-238-Cistus                                                  0.0
# T120-21-BAD-PL-245-Cistus                                                  0.0
# T120-25-BAD-PL-257-Cistus                                                  0.0
# T120-28-BAD-PL-266-Cistus                                                  0.0
# T120-4-VALD-PL-192-Cistus                                                  0.0
# T120-6-VALD-PL-198-Cistus                                                  0.0
# T120-8-VALD-3-PL-205-Cistus                                                0.0
#
# [26 rows x 862 columns]

# %%
print(valid_categories)
# Out:
# {'localidad': ['Valdemaqueda', 'Badajoz', 'Andujar'], 'Sample_from': ['Seed', 'Grown plant'], 'Treatment': ['120_10min', 'Control']}

# %%
# dict wwhere the list will go
list_dict = {}

# generate a sub-df for each category
# and level from 1 to 7

for category, values in valid_categories.items():
    # create category directory (tidier output)
    try:
        os.mkdir(category)
    except FileExistsError:
        pass
    
    # subdict for each category
    list_dict[category] = {}
        
    for value in values:
        # drop metadata columns
        sub_df = full_df[full_df[category] == value].drop(category_names_list, axis=1)        
        spp_name = list(sub_df.columns)
        
        for level in reversed(range(1,8)):
            
            # subdict for the level if it doesnt previously exist
            if level not in list_dict[category]:
                list_dict[category][level] = {}
            list_dict[category][level][value] = {}
                        
            # get the names at that level (7-species)
            trimmed_names = [";".join(item.split(";")[0:level]) for item in spp_name]
                       
            # find those names ending with ";__"
            # ";__" at the end means no identification at that level
            discarded_names = [item for item in trimmed_names if item.endswith(";__")]
            
            # put names on a dict (key: former, val: trimmed)
            changename_dict = {full_name : trimmed_name for full_name, trimmed_name in zip(spp_name,trimmed_names)}
            
            # change the names in the df according to it
            leveled_df = sub_df.rename(columns=changename_dict)
            
            # drop the items in the discarded name from columns
            leveled_df.drop(discarded_names, inplace=True, axis=1)

            # Add up repeated columns
            leveled_df = leveled_df.groupby(leveled_df.columns, axis=1).sum()
            
            # normalize (0: absence, 1: presence)
            leveled_df = normalize_dataframe(leveled_df, criteria=1)
            
            leveled_df.loc["All"] = leveled_df.sum()
            
            # normalize it (I had to do it with a for loop, sorry viewer)
            row_number, col_number = leveled_df.shape
            
            # last row, row_number -1, is the "All" row
            for column in range(0, col_number):
                # first, get the relative abundance of each taxon on each group 
                leveled_df.iloc[row_number-1, column] = leveled_df.iloc[row_number-1, column]*100/(row_number-1) 
            
            # file will contain row: category name, columns: abundance of this taxa in the group
            filename = f"{category}/{category}_lvl{level}.tsv"
            
            if os.path.exists(filename):
                with open(filename, "a") as infile:
                    content = [f"{category}_{value}"] + leveled_df.loc['All'].tolist()
                    for item in content:
                        infile.write(str(item))
                        infile.write("\t")
                    infile.write("\n")
            else:
                # if file dont exist, create header
                with open(filename, "w") as infile:
                    header = ["group"] + list(leveled_df.columns)
                    for item in header:
                        infile.write(item)
                        infile.write("\t")
                    infile.write("\n")
                    
                    content = [f"{category}_{value}"] + leveled_df.loc['All'].tolist()
                    for item in content:
                        infile.write(str(item))
                        infile.write("\t")
                    infile.write("\n")
                    
            for column in range(0, col_number):
                # if present in all, change it to 1
                # else change it to 0
                if leveled_df.iloc[row_number-1, column] < 100:                    
                    leveled_df.iloc[row_number-1, column] = 0
                else:
                    leveled_df.iloc[row_number-1, column] = 1
                    
            for sample in leveled_df.index.tolist():
                list_dict[category][level][value][sample] = leveled_df.loc[sample].index[leveled_df.loc[sample] == 1].tolist()

# %%
with open("organized_presence_list.json","w") as infile:
    json.dump(list_dict, infile, indent=4)

# %% [markdown]
# from matplotlib import pyplot as plt

# %% [markdown]
# from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# from matplotlib_venn import venn3, venn3_circles
