# %%
import argparse
import uuid
import os
import shutil
import pandas as pd
from qiime2 import Visualization
import seaborn as sns; sns.set_theme(color_codes=True)

def save_long_wide(df, filename):
    """
    Generates tsv for a dataframe and for its transposed
    """
    df.to_csv(f"{filename}_wide.tsv", sep="\t")
    df.transpose().to_csv(f"{filename}_long.tsv", sep="\t")
    return

def export_qzv(qzv_in, argument):
    # generate the tmp dir
    # export qzv to a tmp dir
    # get the needed dataframes
    # remove the tmp dir

    tmpdir = str(uuid.uuid4())

    while tmpdir in os.listdir():
        tmpdir = str(uuid.uuid4())

    qzv = Visualization.load(qzv_in)
    qzv.export_data(tmpdir)
    
    # ANCOM table
    df_ancom = pd.read_csv(f"{tmpdir}/ancom.tsv", sep="\t", index_col=0)
    
    # Data table
    df_data = pd.read_csv(f"{tmpdir}/data.tsv", sep="\t", index_col=0)
    newrow = pd.DataFrame.from_dict({argument : ["-","-"]}, orient="index", columns=["W","clr"])
    
    # Generate extra row to avoid NAs    
    df_data = pd.concat([newrow, df_data], axis=0)
    
    # remove the "w"
    df_ancom.drop(["W"], axis=1, inplace=True)
    # Generate extra row to avoid NAs
    newrow = pd.DataFrame.from_dict({argument : ["-"]}, orient="index", columns=["Reject null hypothesis"])
    df_ancom = pd.concat([newrow, df_ancom], axis=0)
    
    # Percent abundances
    df_percent_abundances = pd.read_csv(f"{tmpdir}/percent-abundances.tsv", sep = "\t", index_col=0)
    df_percent_abundances.rename({"Group" : argument},axis=0)
    
    shutil.rmtree(tmpdir)

    return df_ancom, df_data, df_percent_abundances

def get_significative_taxa(df):
    # Get differentially expressed taxa
    # Those with "Reject null hypothesis" set as True
    significative_taxa = df[df["Reject null hypothesis"] == True].index

    if len(significative_taxa) == 0:
        print("No significative data found.")
        return None
    else:
        return list(significative_taxa)
    
def digest_name(string):
    name_as_list = string.replace("d__","domain: " ).replace("p__", "phylum: ").replace("c__", "class: " ).replace("o__", "order: " ).replace("f__","family: " ).replace("g__","genus: "  ).replace("s__","species: ").split(";")
    return name_as_list

# %%
qzv_in = "Assets/ancom_sample-origin_clean_full_6.qzv"
metadata = "Assets/metadata.tsv"
metadata_column = "sample-origin"
rel_freq_in = "Assets/relative_numbers_lvl_6_clean_long.tsv"

# generate the path where the relative abundances will be
# rel_abundances_path = f"../../09-qiime2_collapse_numbers/{args.mode}/{args.state}/lvl_{args.level}/{args.state}/relative_numbers_lvl_{args.level}_{args.state}_long.tsv"

df_ancom, df_data, df_percent_abundances = export_qzv(qzv_in, metadata_column)

# generate first output
df_out_1 = pd.concat([df_ancom, df_data, df_percent_abundances], axis=1)
save_long_wide(df_out_1, "_")

# get the significative data 
significative_taxa = get_significative_taxa(df_out_1)

# import relative abundances
rel_abs_df = pd.read_csv(rel_freq_in, header=0, index_col=0, delimiter="\t")

# Import metadata
column_df = pd.read_csv(metadata, header=0, index_col=0, delimiter="\t").pop(metadata_column)
df_out_2 = pd.concat([df_ancom, df_data, pd.concat([pd.DataFrame(column_df).transpose(), rel_abs_df], axis=0)], axis=1)


# if there are any significative taxa
# generate the heatmap with dendrogram plot
if significative_taxa is not None:
    
    sig_tax_abundances = rel_abs_df.loc[significative_taxa, :]
    
    # change the headers of the table
    # get current names
    rownames = sig_tax_abundances.index
    
    # change current name into new future name
    # Get the values from the wanted columns
    newnames = [digest_name(item) for item in rownames]
    newnames = [f"{item[-1]}; {item[-2]}" if "uncultured" in item[-1] and len(item) > 2 else item[-1] for item in newnames]
    
    namedict = { row : newname for row, newname in zip(rownames, newnames)}
    
    figure_df = sig_tax_abundances.rename(index=namedict)
    
    # associate color code to metadata
    color_codes = dict(zip(column_df.unique(), ["green", "red", "blue", "purple", "grey"]))
    col_colors = column_df.map(color_codes)
    
    figure = sns.clustermap(figure_df,
                  col_colors=col_colors,
                  row_cluster=False,
                  dendrogram_ratio=(0, .15),
                  cbar_pos=(0.9, 0.1, .05, .25),
                  cmap="Greens",
                  figsize=(15,10),
                  )

    figure.savefig("hmap_xsamples_ytaxa.png")
    
    reverse_figure_df = figure_df.transpose()
    
    figure = sns.clustermap(reverse_figure_df,
                            row_colors=col_colors,
                            col_cluster=False,
                            dendrogram_ratio=(0.15, 0),
                            cbar_pos=(0.9, 0.1, .05, .20),
                            cmap="Greens",
                            figsize=(10,15),
                           )
    
    figure.savefig("hmap_xtaxa_ysamples.png")

# %%
df_out_2
# Out:
#                                                    Reject null hypothesis  \
# sample-origin                                                           -
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   True
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   True
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   True
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   True
# ...                                                                   ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                  False
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                  False
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                  False
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                  False
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                  False
#
#                                                       W       clr C-1-Cistus  \
# sample-origin                                         -         -       Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  511   4.38851    90.1648
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  509  -2.18613          0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  499  -1.53386          0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...  498  -1.60078          0
# ...                                                 ...       ...        ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...    2 -0.165928          0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...    2 -0.355231          0
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...    2 -0.323884          0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...    1 -0.399741          0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...    1  -0.71697          0
#
#                                                    C-2-Cistus C-3-Cistus  \
# sample-origin                                            Seed       Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...    96.3598     96.403
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...          0          0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...          0          0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...          0          0
# ...                                                       ...        ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...          0          0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...          0          0
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...          0          0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...          0          0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...          0          0
#
#                                                    T120-1-Cistus  \
# sample-origin                                               Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...       99.4365
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...             0
# ...                                                          ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...             0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...             0
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...             0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...             0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...             0
#
#                                                    T120-2-Cistus  \
# sample-origin                                               Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...       98.6171
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...             0
# ...                                                          ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...             0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...             0
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...             0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...             0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...             0
#
#                                                    T120-3-Cistus  \
# sample-origin                                               Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...         99.64
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...             0
# ...                                                          ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...             0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...             0
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...             0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...             0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...             0
#
#                                                    C-11-AND-PL-31-Cistus  ...  \
# sample-origin                                                Grown plant  ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...              0.272116  ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                5.1394  ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...               1.87144  ...
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...               9.30842  ...
# ...                                                                  ...  ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                     0  ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...               2.03317  ...
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...              0.305489  ...
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                     0  ...
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...               4.11254  ...
#
#                                                    T120-11-AND-PL-214-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                  0.131832
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   10.9383
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   1.20909
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   5.74033
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                  0.610192
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                  0.576293
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                   2.50104
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                   1.79668
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                  0.316396
#
#                                                    T120-12-AND-PL-217-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0.0320577
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   19.2186
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   2.30815
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   2.56061
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                   5.52194
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   1.11401
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                   0.34462
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                   8.10258
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                  0.725306
#
#                                                    T120-16-AND-2-PL-229-Cistus  \
# sample-origin                                                      Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    0.050939
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     14.4836
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     4.66941
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                     10.3576
# ...                                                                        ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                           0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                    0.560329
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                    0.288654
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                   0.0611268
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                     4.74072
#
#                                                    T120-19-AND-PL-238-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                         0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   2.79516
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   21.7036
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   4.18271
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                         0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                    0.1564
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                   1.18303
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                         0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                  0.324832
#
#                                                    T120-21-BAD-PL-245-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                         0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    12.716
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    6.2482
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                    8.0154
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                         0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                  0.550677
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0.0503887
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                         0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                   10.3333
#
#                                                    T120-25-BAD-PL-257-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0.0267389
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   14.9972
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   3.47605
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   15.7158
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                  0.401083
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                  0.628363
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                  0.217253
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                  0.324209
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                   1.60099
#
#                                                    T120-28-BAD-PL-266-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                         0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   12.2257
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   3.43344
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                    7.5666
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                         0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                  0.512843
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                  0.391151
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                         0
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                   0.90834
#
#                                                    T120-4-VALD-PL-192-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                  0.205687
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   5.49699
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   3.72294
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   4.11375
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                 0.0977014
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                         0
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                         0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                   1.65578
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                   4.48912
#
#                                                    T120-6-VALD-PL-198-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                  0.014708
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   31.0781
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    7.8335
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                    10.981
# ...                                                                      ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                  0.641271
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                 0.0941315
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                   0.10884
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                   1.19135
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                  0.429475
#
#                                                    T120-8-VALD-3-PL-205-Cistus
# sample-origin                                                      Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    0.117192
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     5.09786
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     1.77741
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                     12.2505
# ...                                                                        ...
# d__Bacteria;p__Firmicutes;c__Clostridia;o__Lach...                     4.55096
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                    0.550803
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                           0
# d__Bacteria;p__Firmicutes;c__Negativicutes;o__V...                     17.9773
# d__Bacteria;p__Patescibacteria;c__Saccharimonad...                     1.41802
#
# [513 rows x 29 columns]

# %%
level = 7
state = "clean"
mode = "full" 

relevant_rows = [metadata_column] + significative_taxa

print(relevant_rows)

df_out_3 = df_out_2.loc[relevant_rows, :]

# New row for columns
level_row = pd.DataFrame([
    ["-"] + [mode] * (df_out_3.shape[0]-1),
    ["-"] + [level] * (df_out_3.shape[0]-1),
    ["-"] + [state] * (df_out_3.shape[0]-1)    
]).transpose()

level_row

level_row.columns = ["Mode","Level","State"]
level_row.index = df_out_3.index

df_out_3 = pd.concat([level_row, df_out_3], axis=1)
# Out:
# ['sample-origin', 'd__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Erwiniaceae;g__Pantoea', 'd__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales;f__Comamonadaceae;g__uncultured', 'd__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales;f__Comamonadaceae;g__Variovorax', 'd__Bacteria;p__Chloroflexi;c__Chloroflexia;o__Chloroflexales;f__Roseiflexaceae;g__uncultured', 'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales;f__Rhizobiaceae;g__Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium', 'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales;f__Xanthobacteraceae;g__Bradyrhizobium', 'd__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Chitinophagales;f__Chitinophagaceae;g__Niastella']

# %%
df_out_3
# Out:
#                                                     Mode Level  State  \
# sample-origin                                          -     -      -
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  full     7  clean
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  full     7  clean
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  full     7  clean
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...  full     7  clean
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  full     7  clean
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  full     7  clean
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...  full     7  clean
#
#                                                    Reject null hypothesis  \
# sample-origin                                                           -
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   True
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   True
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   True
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   True
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   True
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   True
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                   True
#
#                                                       W       clr C-1-Cistus  \
# sample-origin                                         -         -       Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  511   4.38851    90.1648
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  509  -2.18613          0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...  499  -1.53386          0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...  498  -1.60078          0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  497  -1.36127  0.0613112
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...  488 -0.910693          0
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...  485  -1.08893          0
#
#                                                    C-2-Cistus C-3-Cistus  \
# sample-origin                                            Seed       Seed
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...    96.3598     96.403
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...          0          0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...          0          0
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...          0          0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...          0          0
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...          0          0
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...          0          0
#
#                                                    T120-1-Cistus  ...  \
# sample-origin                                               Seed  ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...       99.4365  ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0  ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...             0  ...
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...             0  ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...             0  ...
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...             0  ...
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...             0  ...
#
#                                                    T120-11-AND-PL-214-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                  0.131832
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   10.9383
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   1.20909
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   5.74033
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   2.71197
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   4.32031
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                    2.8551
#
#                                                    T120-12-AND-PL-217-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0.0320577
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   19.2186
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   2.30815
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   2.56061
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   6.23522
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                    1.8914
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                  0.773392
#
#                                                    T120-16-AND-2-PL-229-Cistus  \
# sample-origin                                                      Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    0.050939
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     14.4836
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     4.66941
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                     10.3576
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                     1.41271
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                     2.76429
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                     6.81903
#
#                                                    T120-19-AND-PL-238-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                         0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   2.79516
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   21.7036
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   4.18271
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   4.48749
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   1.21912
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                    1.6803
#
#                                                    T120-21-BAD-PL-245-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                         0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    12.716
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    6.2482
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                    8.0154
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   3.09891
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   1.24172
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                   2.77498
#
#                                                    T120-25-BAD-PL-257-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0.0267389
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   14.9972
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   3.47605
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   15.7158
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   4.69601
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   2.64046
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                   3.85374
#
#                                                    T120-28-BAD-PL-266-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                         0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   12.2257
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   3.43344
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                    7.5666
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   1.66891
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   3.36825
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                     6.115
#
#                                                    T120-4-VALD-PL-192-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                  0.205687
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   5.49699
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   3.72294
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                   4.11375
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                    2.8282
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   1.84604
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                   2.43739
#
#                                                    T120-6-VALD-PL-198-Cistus  \
# sample-origin                                                    Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                  0.014708
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                   31.0781
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    7.8335
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                    10.981
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   5.80968
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                   1.66789
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                   1.04427
#
#                                                    T120-8-VALD-3-PL-205-Cistus
# sample-origin                                                      Grown plant
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                    0.117192
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     5.09786
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...                     1.77741
# d__Bacteria;p__Chloroflexi;c__Chloroflexia;o__C...                     12.2505
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                     2.38681
# d__Bacteria;p__Proteobacteria;c__Alphaproteobac...                     2.79308
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__C...                      1.7696
#
# [8 rows x 32 columns]

# %%
headers = pd.DataFrame(df_out_3.iloc[1]).transpose()

# %%
headers
# Out:
#      0      1      2                       3  4    5           6           7   \
# 0  Mode  Level  State  Reject null hypothesis  W  clr  C-1-Cistus  C-2-Cistus
#
#            8              9   ...                         22  \
# 0  C-3-Cistus  T120-1-Cistus  ...  T120-11-AND-PL-214-Cistus
#
#                           23                           24  \
# 0  T120-12-AND-PL-217-Cistus  T120-16-AND-2-PL-229-Cistus
#
#                           25                         26  \
# 0  T120-19-AND-PL-238-Cistus  T120-21-BAD-PL-245-Cistus
#
#                           27                         28  \
# 0  T120-25-BAD-PL-257-Cistus  T120-28-BAD-PL-266-Cistus
#
#                           29                         30  \
# 0  T120-4-VALD-PL-192-Cistus  T120-6-VALD-PL-198-Cistus
#
#                             31
# 0  T120-8-VALD-3-PL-205-Cistus
#
# [1 rows x 32 columns]

# %% [markdown]
# # Abs_count, Rel_count, Prevalence, Cleaning, Repeat

# %%
from qiime2 import Artifact
import pandas as pd

import sys
import os

# %%
def save_long_wide(df, filename):
    """
    Generates tsv for a dataframe and for its transposed
    """
    
    df.to_csv(f"{filename}_wide.tsv", sep="\t")
    df.transpose().to_csv(f"{filename}_long.tsv", sep="\t")
    return

def relative_abundances(df):
    """
    Obtain the relative abundance of the otus
    """
    
    df["Total"] = df.sum(axis=1)
    rownum, colnum = df.shape
    for row in range(rownum):
        for col in range(colnum-1):
            df.iloc[row, col] = df.iloc[row, col] * 100 / df.iloc[row, colnum-1]

    df.drop("Total", axis=1, inplace=True)   
    
    return df
    
def normalize_dataframe(dataframe, criteria=0):
    """
    Change the dataframe to an absence-presence matrix
    based on a criteria (by now, a number)
    """
    
    row_number, col_number = dataframe.shape
    
    for row in range(0, row_number):
        for col in range(0, col_number):
            if dataframe.iloc[row, col] >= criteria:
                
                print(f"{dataframe.iloc[row, col]} is considered 1")
                
                dataframe.iloc[row, col] = 1
            else:
                print(f"{dataframe.iloc[row, col]} is considered 0")

                dataframe.iloc[row, col] = 0
                
    return dataframe

def create_category_dict(metadata):
    """
    Create, from the metadata dataframe, a dict with
    key: category; val: values in that category
    if only one category, it wont be taken into account
    """
    valid_categories = dict()
    category_names_list = list(metadata.columns)

    # get all different possibilities for each metadata column
    for col_index in range(metadata.shape[1]):
        
        # list from a set to avoid repeating
        groups = (list(set(metadata[category_names_list[col_index]])))
        
        # if more than 1 different category, add it to the dict
        if len(groups) > 1:
            category_name = category_names_list[col_index]
            valid_categories[category_name] = [item for item in groups]

    return valid_categories, category_names_list

def prevalences(df, metadata):
    """
    Calculate the prevalence for each group
    """
    
    df_prev = pd.concat([df, metadata], axis=1)
    category_dict, category_names_list = create_category_dict(metadata)
    
    for category, values in category_dict.items():
    
        prevalence_per_value = []

        for value in values:

            # Drop metadata columns
            sub_df = df_prev[df_prev[category] == value].drop(category_names_list, axis=1)
            
            # Normalize (0: absence, 1: presence)
            norm_df = normalize_dataframe(sub_df, criteria=1)
            norm_df.loc["Prevalence"] = norm_df.sum(axis=0)
            
            
            norm_df.transpose().to_csv("normalizada.tsv",sep="\t")


            row_number, col_number = norm_df.shape
        
            for column in range(0, col_number):
                # Get the relative abundance of each taxon on each group
                norm_df.iloc[row_number-1, column] = norm_df.iloc[row_number-1, column]*100/(row_number-1)
                norm_df.rename({"Prevalence":value}, axis=0, inplace=True)

            prevalence_per_value.append(norm_df.loc[value].to_frame().transpose())        
        
        prevalence_df = pd.concat(prevalence_per_value)
        
        save_long_wide(prevalence_df, f"prevalence")  
    

def clean_dataframe(df):
    """
    Remove the columns ending with ;__
    """
    
    df = df.loc[:,~df.columns.str.endswith(";__")]

    return df


def artifact_from_df(df_in, filename):
    
    clean_qza = Artifact.import_data("FeatureTable[Frequency]", df_in)
    clean_qza.save(f"{filename}.qza")
    
    return

# %%
qza_in = "Assets/collapsed_raw_full_table_lvl_5.qza"

# %%
df = Artifact.load(qza_in).view(pd.DataFrame)

# %%
save_long_wide(df,"absolute_numbers")

# %%
rel_df = relative_abundances(df)
save_long_wide(rel_df,"relative_numbers")

# %%
metadata_file = "Assets/metadata.tsv"

metadata = pd.read_csv(
    metadata_file,
    sep='\t',
    header=0,
    index_col=0
    )
prevalences(df, metadata)

# %%
clean = clean_dataframe(df)

artifact_from_df(clean, "table_clean")

# %% [markdown]
# # Prevalence

# %%
import sys
import os

import pandas as pd
from qiime2 import Artifact

# %%
def normalize_dataframe(dataframe, criteria=0):
    """
    Change the dataframe to an absence-presence matrix
    based on a criteria (by now, a number)
    """
    
    row_number, col_number = dataframe.shape
    
    for row in range(0, row_number):
        for col in range(0, col_number):
            if dataframe.iloc[row, col] >= criteria:
                dataframe.iloc[row, col] = 1
            else:
                dataframe.iloc[row, col] = 0
                
    return dataframe

def create_category_dict(metadata):
    """
    Create, from the metadata dataframe, a dict with
    key: category; val: values in that category
    if only one category, it wont be taken into account
    """
    valid_categories = dict()
    category_names_list = list(metadata.columns)

    # get all different possibilities for each metadata column
    for col_index in range(metadata.shape[1]):
        
        # list from a set to avoid repeating
        groups = (list(set(metadata[category_names_list[col_index]])))
        
        # if more than 1 different category, add it to the dict
        if len(groups) > 1:
            category_name = category_names_list[col_index]
            valid_categories[category_name] = [item for item in groups]

    return valid_categories, category_names_list

# %%
qza_in = "Assets/collapsed_raw_full_table_lvl_5.qza"
metadata_file = "Assets/metadata.tsv"
lvl = 6

# %%
try:
    os.mkdir(f"prevalence")
except:
    pass
qza = Artifact.load(qza_in)
counts = qza.view(pd.DataFrame)

metadata = pd.read_csv(
    metadata_file,
    sep='\t',
    header=0,
    index_col=0
    )
full_df = pd.concat([metadata, counts], axis=1)

# %%
counts

# %%
metadata

# %%
full_df

# %%
valid_categories, category_names_list = create_category_dict(metadata)

# %%
valid_categories

# %%
category_names_list

# %%
for category, values in valid_categories.items():
    
    prevalence_per_value = []
    
    # print(category)
    for value in values:
        # print(value)
        # Drop metadata columns
        sub_df = full_df[full_df[category] == value].drop(category_names_list, axis=1)
        # Normalize (0: absence, 1: presence)
        norm_df = normalize_dataframe(sub_df, criteria=1)
        norm_df.loc["Prevalence"] = norm_df.sum(axis=0)
        
        row_number, col_number = norm_df.shape
        
        # data
        
        for column in range(0, col_number):
            # Get the relative abundance of each taxon on each group
            norm_df.iloc[row_number-1, column] = norm_df.iloc[row_number-1, column]*100/(row_number-1)
        norm_df.rename({"Prevalence":value}, axis=0, inplace=True)
        
        prevalence_per_value.append(norm_df.loc[value].to_frame().transpose())        
        
    prevalence_df = pd.concat(prevalence_per_value)
    
    prevalence_df.to_csv(f"prevalence_lvl_{lvl}_{category}_{value}_wide.tsv", sep="\t")
    prevalence_df.transpose().to_csv(f"prevalence_lvl_{lvl}_{category}_{value}_long.tsv", sep="\t")

# %%
norm_df

# %%
prevalence_df

# %% [markdown]
# # RELATIVE COUNTS

# %%
import shutil
import os
import sys

import pandas as pd
from qiime2 import Artifact

# %%
filename = "Assets/collapsed_raw_full_table_lvl_5.qza"
outdir = "lvl6"

# %%
# Open visualization
qza_artifact = Artifact.load(filename)
df = qza_artifact.view(pd.DataFrame)

# %%
df

# %%
df["Total"] = df.sum(axis=1)

# %%
df

# %%
rownum, colnum = df.shape
for row in range(rownum):
    for col in range(colnum-1):
        df.iloc[row, col] = df.iloc[row, col] * 100 / df.iloc[row, colnum-1]

df.drop("Total", axis=1)
df.to_csv("relativ_freq.tsv", sep="\t")

# %%
df

# %%
df["Total"] = df.sum()
# Delete unwanted dirs & files
# Hardcoded but its always the same so
dirs_to_del = ["css", "js", "q2templateassets"]

for folder in dirs_to_del:
    shutil.rmtree(f"{outdir}/{folder}")

files_to_del = ["index.html"]
for file in files_to_del:
    os.remove(f"{outdir}/{file}")

# %%
df = pd.read_csv(f"{outdir}/metadata.tsv", sep="\t", header=0, index_col=0)

df = df.drop("#q2:types")
df.to_csv(f"{table_name}.tsv", sep="\t")
df.transpose().to_csv(f"{table_name}_long.tsv", sep="\t")

# %% [markdown]
# # ANCOM

# %%
import sys
import os
import shutil

import pandas as pd
from qiime2 import Visualization
import seaborn as sns; sns.set_theme(color_codes=True)

# %%
# ANCOM qzv file
qzv_in = "Assets/ancom_sample-origin_full.qzv"
tmpdir = "tmp"
rel_feat_table = "Assets/relativ_freq.tsv"

# %%
 def export_qzv(qzv_in, tmpdir):
    # export qzv to a tmp dir
    # get the needed dataframes
    # remove the tmp dir
    qzv = Visualization.load(qzv_in)
    qzv.export_data(tmpdir)
    
    # ancom table
    df_ancom = pd.read_csv(f"{tmpdir}/ancom.tsv", sep="\t", index_col=0)
    
    # Data table
    df_data = pd.read_csv(f"{tmpdir}/data.tsv", sep="\t", index_col=0)
    
    # Add extra row to avoid NAs
    df_data.loc["Group"] = 2 * ["-"]
    
    # remove the "w"
    df_ancom.drop(["W"], axis=1, inplace=True)

    # Percent abundances
    df_percent_abundances = pd.read_csv(f"{tmpdir}/percent-abundances.tsv", sep = "\t", index_col=0)

    shutil.rmtree(tmpdir)

    return df_ancom, df_data, df_percent_abundances

# %%
def get_significative_taxa(df):
    # Get differentially expressed taxa
    significative_df = df[df["Reject null hypothesis"] == True].loc[:,["Reject null hypothesis", "clr", "W"]]
    significative_taxa = list(significative_df.index)

    if len(significative_taxa) == 0:
        print("No significative data found.")
        return None
    else:
        return significative_taxa

# %%
relfq_df = pd.read_csv(rel_feat_table, sep="\t", header=0, index_col=0)
relfq_df

# %%
relqf_df = relfq_df.transpose().loc[significative_taxa]

# %%
relqf_df.loc["Metadata group"] = ["a"] * 26
relqf_df

# %%
final_df = pd.concat([significative_df,relqf_df], axis=1)

# %%
final_df
